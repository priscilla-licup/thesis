# %% [markdown]
# # GPU Setup

# %%
# import tensorflow as tf
# gpus = tf.config.list_physical_devices("GPU")
# if gpus:
#     for gpu in gpus:
#         print("Found a GPU with the name:", gpu)
# else:
#     print("Failed to detect a GPU.")

# %%
import torch

# Check if GPU is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Using GPU: NVIDIA GeForce RTX 3060

# %% [markdown]
# # Libraries

# %%
import pymongo
import tensorflow as tf
from transformers import AutoTokenizer, TFAutoModel
from langchain.text_splitter import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer

# %% [markdown]
# # MongoDB Connection

# %%
# MongoDB Connection String
client = pymongo.MongoClient("mongodb+srv://priscillalicup:HheKWY3scWfSLsrn@cluster0.uskxsig.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client.supreme_court_jurisprudence
collection = db.year_2012_zip

# %% [markdown]
# # Tokens and Models

# %%
# Load TensorFlow model and tokenizer
# model_name = "sentence-transformers/all-MiniLM-L6-v2"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = TFAutoModel.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['embeddings.position_ids']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
# Ensure GPU usage for SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2', device=device)

# %% [markdown]
# # Recursive Chunking Function

# %%
# Recursive Chunking
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=0,
    separators=["\n\n", "\n", "(?<=\. )", " "],
    length_function=len
)

# %% [markdown]
# Using TF (not successful yet)

# %%
# # Generate Embedding function using TensorFlow

# Makes nested array embeddings
# def generate_embedding(text: str) -> 'list[float]':
#     # inputs = tokenizer(text, return_tensors="tf", truncation=True, padding=True)
#     # outputs = model(inputs)
#     # return outputs.last_hidden_state[:, 0, :].numpy().tolist()
#     return model.encode(text).tolist()

# Working (?)
# def generate_embedding(text: str) -> list:
#     inputs = tokenizer(text, return_tensors="tf", truncation=True, padding=True)
#     outputs = model(inputs)
#     embeddings = outputs.last_hidden_state[:, 0, :].numpy()
#     return embeddings.flatten().tolist()

# %% [markdown]
# # Embedding Function

# %%
def generate_embedding(text):
  return model.encode(text).tolist()

# %% [markdown]
# Trial for embedding 1 document in MongoDB

# %%
# # TRIAL
# from bson import ObjectId

# # Ensure you import ObjectId from bson to work with MongoDB document IDs
# doc_id = ObjectId('664e4e1e1fd27d4ee67ccb12')


# try:
#     # Find the specific document by its ObjectId
#     doc = collection.find_one({'_id': doc_id})
    
#     if doc:
        
#         # Chunk the document text
#         chunks = text_splitter.split_text(doc['text'])

#         # Generate embeddings for each chunk
#         chunk_embeddings = [generate_embedding(chunk) for chunk in chunks]

#         # Store the chunks and their embeddings in the document
#         doc['text_chunks'] = chunks
#         doc['text_chunk_embeddings'] = chunk_embeddings

#         collection.replace_one({'_id': doc['_id']}, doc)
#         print(f"Successfully embedded data from {str(doc['identifier'])}")
#         counter += 1
#     else:
#         print(f"No document found with ID: {doc_id}")
# except Exception as e:
#     print(f"An error occurred: {e}")
# finally:
#     print(f"Number of documents embedded: {counter}")
# Out:
# Successfully embedded data from A.C. No. 5098
# Number of documents embedded: 717

# %% [markdown]
# Embedding all documents in a DB

# %%
# ONLY RUN IF NO EMBEDDINGS IN DATABASE YET

# Append embeddings to MongoDB
# -------------------------------------------- COMMENT OUT BELOW
# counter = 0
# try:
#     for doc in collection.find({'text': {"$exists": True}}):
#         # Check if embeddings already exist
#         if 'text_chunk_embeddings' in doc:
#             print(f"Embeddings already exist for document {str(doc['identifier'])}")
#             counter += 1
#             continue

#         # Chunk the document text
#         chunks = text_splitter.split_text(doc['text'])

#         # Generate embeddings for each chunk
#         chunk_embeddings = [generate_embedding(chunk) for chunk in chunks]

#         # Store the chunks and their embeddings in the document
#         doc['text_chunks'] = chunks
#         doc['text_chunk_embeddings'] = chunk_embeddings

#         collection.replace_one({'_id': doc['_id']}, doc)
#         print(f"Successfully embedded data from {str(doc['identifier'])}")
#         counter += 1
# except Exception as e:
#     print(f"An error occurred: {e}")
# finally:
#     print(f"Number of documents embedded: {counter}")
# Out:
# Successfully embedded data from A.C. No. 5098
# Successfully embedded data from A.C. No. 6332
# Successfully embedded data from A.C. No. 6903
# Successfully embedded data from A.C. No. 7481
# Successfully embedded data from A.C. No. 7880
# Successfully embedded data from A.C. No. 7940
# Successfully embedded data from A.M. No. MTJ-07-1667
# Successfully embedded data from A.M. No. MTJ-08-1711
# Successfully embedded data from A.M. No. MTJ-11-1781 (Formerly OCA I.P.I. No. 09-2161-MTJ)
# Successfully embedded data from A.M. No. P-09-2720 [Formerly OCA I.P.I. No. 09-3259-P]
# Successfully embedded data from A.M. No. P-11-2912
# Successfully embedded data from A.M. No. P-11-2948 [Formerly OCA I.P.I. No. 09-3049-P]
# Successfully embedded data from A.M. No. P-11-3002 (Formerly A.M. No. 11-9-96-MTCC)
# Successfully embedded data from A.M. No. P-11-3003 (Formerly A.M. IPI No. 08-2970-P)
# Successfully embedded data from A.M. No. P-11-3004 (Formerly OCA I.P.I. No. 10-3483-P)
# Successfully embedded data from A.M. No. P-12-3028 [Formerly OCA IPI No. 11-3649-P]
# Successfully embedded data from A.M. No. P-12-3053 (formerly A.M. No. 06-3-88-MTCC)
# Successfully embedded data from A.M. No. P-12-3058 [Formerly A.M. OCA I.P.I. No. 10-3357-P]
# Successfully embedded data from A.M. No. RTJ-10-2232
# Successfully embedded data from G.R. No. 143264
# Successfully embedded data from G.R. No. 161909
# Successfully embedded data from G.R. No. 163125
# Successfully embedded data from G.R. No. 163657
# Successfully embedded data from G.R. No. 163700
# Successfully embedded data from G.R. No. 164457
# Successfully embedded data from G.R. No. 164987
# Successfully embedded data from G.R. No. 167057
# Successfully embedded data from G.R. No. 167735
# Successfully embedded data from G.R. No. 170290
# Successfully embedded data from G.R. No. 170425
# Successfully embedded data from G.R. No. 170865
# Successfully embedded data from G.R. No. 171101
# Successfully embedded data from G.R. No. 171995
# Successfully embedded data from G.R. No. 172538
# Successfully embedded data from G.R. No. 173320
# Successfully embedded data from G.R. No. 173820
# Successfully embedded data from G.R. No. 173840
# Successfully embedded data from G.R. No. 173844
# Successfully embedded data from G.R. No. 173870
# Successfully embedded data from G.R. No. 173951
# Successfully embedded data from G.R. No. 174118
# Successfully embedded data from G.R. No. 174489
# Successfully embedded data from G.R. No. 175039
# Successfully embedded data from G.R. No. 175042
# Successfully embedded data from G.R. No. 175139
# Successfully embedded data from G.R. No. 175303
# Successfully embedded data from G.R. No. 175763
# Successfully embedded data from G.R. No. 177224
# Successfully embedded data from G.R. No. 177611
# Successfully embedded data from G.R. No. 177761
# Successfully embedded data from G.R. No. 179488
# Successfully embedded data from G.R. No. 179936
# Successfully embedded data from G.R. No. 180177
# Successfully embedded data from G.R. No. 180898
# Successfully embedded data from G.R. No. 181367
# Successfully embedded data from G.R. No. 181544
# Successfully embedded data from G.R. No. 182331
# Successfully embedded data from G.R. No. 183308
# Successfully embedded data from G.R. No. 183706
# Successfully embedded data from G.R. No. 183916
# Successfully embedded data from G.R. No. 184282
# Successfully embedded data from G.R. No. 184528
# Successfully embedded data from G.R. No. 184926
# Successfully embedded data from G.R. No. 185829
# Successfully embedded data from G.R. No. 185918
# Successfully embedded data from G.R. No. 186141
# Successfully embedded data from G.R. No. 187919
# Successfully embedded data from G.R. No. 188322
# Successfully embedded data from G.R. No. 188497
# Successfully embedded data from G.R. No. 188661
# Successfully embedded data from G.R. No. 188921
# Successfully embedded data from G.R. No. 189127
# Successfully embedded data from G.R. No. 189434
# Successfully embedded data from G.R. No. 190321
# Successfully embedded data from G.R. No. 190569
# Successfully embedded data from G.R. No. 190610
# Successfully embedded data from G.R. No. 190749
# Successfully embedded data from G.R. No. 191970
# Successfully embedded data from G.R. No. 192190
# Successfully embedded data from G.R. No. 192514
# Successfully embedded data from G.R. No. 192737
# Successfully embedded data from G.R. No. 192791
# Successfully embedded data from G.R. No. 193250
# Successfully embedded data from G.R. No. 193261
# Successfully embedded data from G.R. No. 193415
# Successfully embedded data from G.R. No. 193443
# Successfully embedded data from G.R. No. 193509
# Successfully embedded data from G.R. No. 194024
# Successfully embedded data from G.R. No. 194677
# Successfully embedded data from G.R. No. 194813
# Successfully embedded data from G.R. No. 197807
# Successfully embedded data from G.R. No. 200030
# Successfully embedded data from G.R. Nos. 147036-37
# Successfully embedded data from G.R. Nos. 184379-80
# Successfully embedded data from A.C. No. 6116
# Successfully embedded data from A.C. No. 9074
# Successfully embedded data from A.C. No. 9094
# Successfully embedded data from A.C. No. 9259
# Successfully embedded data from A.C. No. 9390
# Successfully embedded data from A.M. No. P-10-2809
# Successfully embedded data from A.M. No. P-12-3029 (Formerly OCA I.P.I. No. 08-2850-P)
# Successfully embedded data from A.M. No. P-12-3033 (Formerly A.M. No. 10-8-97-MeTC)
# Successfully embedded data from A.M. No. P-12-3080 [FORMERLY OCA I.P.I. NO. 10-3543-P]
# Successfully embedded data from A.M. No. P-12-3084 [Formerly A.M. No. 12-4-33-MCTC]
# Successfully embedded data from G.R. No. 137582
# Successfully embedded data from G.R. No. 154213
# Successfully embedded data from G.R. No. 155830
# Successfully embedded data from G.R. No. 157917
# Successfully embedded data from G.R. No. 158461
# Successfully embedded data from G.R. No. 159508
# Successfully embedded data from G.R. No. 160444
# Successfully embedded data from G.R. No. 163026
# Successfully embedded data from G.R. No. 163286
# Successfully embedded data from G.R. No. 163859
# Successfully embedded data from G.R. No. 164258
# Successfully embedded data from G.R. No. 165166
# Successfully embedded data from G.R. No. 166660
# Successfully embedded data from G.R. No. 168856
# Successfully embedded data from G.R. No. 169254
# Successfully embedded data from G.R. No. 171076
# Successfully embedded data from G.R. No. 171132
# Successfully embedded data from G.R. No. 171182
# Successfully embedded data from G.R. No. 172008
# Successfully embedded data from G.R. No. 173268
# Successfully embedded data from G.R. No. 173474
# Successfully embedded data from G.R. No. 174431
# Successfully embedded data from G.R. No. 174646
# Successfully embedded data from G.R. No. 175256
# Successfully embedded data from G.R. No. 175301
# Successfully embedded data from G.R. No. 175678
# Successfully embedded data from G.R. No. 175969
# Successfully embedded data from G.R. No. 176984
# Successfully embedded data from G.R. No. 177137
# Successfully embedded data from G.R. No. 177903
# Successfully embedded data from G.R. No. 177907
# Successfully embedded data from G.R. No. 178288
# Successfully embedded data from G.R. No. 179232
# Successfully embedded data from G.R. No. 179677
# Successfully embedded data from G.R. No. 180614
# Successfully embedded data from G.R. No. 181180
# Successfully embedded data from G.R. No. 182435
# Successfully embedded data from G.R. No. 184746
# Successfully embedded data from G.R. No. 186169
# Successfully embedded data from G.R. No. 186993
# Successfully embedded data from G.R. No. 187451
# Successfully embedded data from G.R. No. 187713
# Successfully embedded data from G.R. No. 187734
# Successfully embedded data from G.R. No. 188854
# Successfully embedded data from G.R. No. 189529
# Successfully embedded data from G.R. No. 189998
# Successfully embedded data from G.R. No. 190071
# Successfully embedded data from G.R. No. 190144
# Successfully embedded data from G.R. No. 190907
# Successfully embedded data from G.R. No. 191192
# Successfully embedded data from G.R. No. 191532
# Successfully embedded data from G.R. No. 191606
# Successfully embedded data from G.R. No. 191792
# Successfully embedded data from G.R. No. 192908
# Successfully embedded data from G.R. No. 194721
# Successfully embedded data from G.R. No. 195097
# Successfully embedded data from G.R. No. 195243
# Successfully embedded data from G.R. No. 195307
# Successfully embedded data from G.R. No. 195428
# Successfully embedded data from G.R. No. 196883
# Successfully embedded data from G.R. No. 198742
# Successfully embedded data from G.R. No. 199877
# Successfully embedded data from G.R. No. 200134
# Successfully embedded data from G.R. Nos. 166948-59
# Successfully embedded data from A.M. No. 09-5-2-SC
# Successfully embedded data from A.M. No. 12-8-160-RTC
# Successfully embedded data from A.M. No. MTJ-10-1772
# Successfully embedded data from A.M. No. P-08-2418 (Formerly OCA IPI No. 05-2152-P)
# Successfully embedded data from A.M. No. RTJ-12-2331 (Formerly OCA I.P.I. No. 11-3776-RTJ)
# Successfully embedded data from ADM. CASE No. 8383
# Successfully embedded data from G.R. No. 162930
# Successfully embedded data from G.R. No. 164201
# Successfully embedded data from G.R. No. 170217
# Successfully embedded data from G.R. No. 170488
# Successfully embedded data from G.R. No. 172086
# Successfully embedded data from G.R. No. 172338
# Successfully embedded data from G.R. No. 173606
# Successfully embedded data from G.R. No. 174300
# Successfully embedded data from G.R. No. 174647
# Successfully embedded data from G.R. No. 175491
# Successfully embedded data from G.R. No. 176898
# Successfully embedded data from G.R. No. 177042
# Successfully embedded data from G.R. No. 177086
# Successfully embedded data from G.R. No. 178607
# Successfully embedded data from G.R. No. 180440
# Successfully embedded data from G.R. No. 181138
# Successfully embedded data from G.R. No. 181202
# Successfully embedded data from G.R. No. 181623
# Successfully embedded data from G.R. No. 181891
# Successfully embedded data from G.R. No. 185005
# Successfully embedded data from G.R. No. 185945
# Successfully embedded data from G.R. No. 187337
# Successfully embedded data from G.R. No. 188107
# Successfully embedded data from G.R. No. 188345
# Successfully embedded data from G.R. No. 188575
# Successfully embedded data from G.R. No. 189277
# Successfully embedded data from G.R. No. 191281
# Successfully embedded data from G.R. No. 191660
# Successfully embedded data from G.R. No. 191890
# Successfully embedded data from G.R. No. 191993
# Successfully embedded data from G.R. No. 194270
# Successfully embedded data from G.R. No. 195640
# Successfully embedded data from G.R. No. 195670
# Successfully embedded data from G.R. No. 196171
# Successfully embedded data from G.R. No. 198051
# Successfully embedded data from G.R. No. 198357
# Successfully embedded data from G.R. No. 198701
# Successfully embedded data from G.R. No. 198820
# Successfully embedded data from G.R. No. 199481
# Successfully embedded data from G.R. No. 199579
# Successfully embedded data from G.R. No. 199892
# Successfully embedded data from G.R. No. 200531
# Successfully embedded data from G.R. No.181021
# Successfully embedded data from G.R. Nos. 174457-59
# Successfully embedded data from A.C. No. 7430
# Successfully embedded data from A.C. No. 8254 (Formerly CBD Case No. 04-1310)
# Successfully embedded data from A.M. No. 11-10-7-SC
# Successfully embedded data from A.M. No. MTJ-10-1761
# Successfully embedded data from A.M. No. P-06-2111
# Successfully embedded data from A.M. No. P-11-2926
# Successfully embedded data from A.M. No. P-11-2951 (Formerly A.M. No. 10-3544-P)
# Successfully embedded data from A.M. No. P-11-2999 [formerly OCA IPI No. 10-3517-P]
# Successfully embedded data from A.M. No. RTJ-10-2255  (Formerly OCA I.P.I. No. 10-3335-RTJ)
# Successfully embedded data from A.M. No. RTJ-11-2291
# Successfully embedded data from A.M. No. RTJ-11-2298
# Successfully embedded data from G.R. No. 151258
# Successfully embedded data from G.R. No. 152262
# Successfully embedded data from G.R. No. 157810
# Successfully embedded data from G.R. No. 157838
# Successfully embedded data from G.R. No. 158379
# Successfully embedded data from G.R. No. 158413
# Successfully embedded data from G.R. No. 160278
# Successfully embedded data from G.R. No. 161771
# Successfully embedded data from G.R. No. 161796
# Successfully embedded data from G.R. No. 162196
# Successfully embedded data from G.R. No. 165413
# Successfully embedded data from G.R. No. 165935
# Successfully embedded data from G.R. No. 167952
# Successfully embedded data from G.R. No. 169055
# Successfully embedded data from G.R. No. 169903
# Successfully embedded data from G.R. No. 170098
# Successfully embedded data from G.R. No. 171513
# Successfully embedded data from G.R. No. 171701
# Successfully embedded data from G.R. No. 172223
# Successfully embedded data from G.R. No. 172448
# Successfully embedded data from G.R. No. 172455
# Successfully embedded data from G.R. No. 173008
# Successfully embedded data from G.R. No. 173128
# Successfully embedded data from G.R. No. 173291
# Successfully embedded data from G.R. No. 173476
# Successfully embedded data from G.R. No. 173531
# Successfully embedded data from G.R. No. 173882
# Successfully embedded data from G.R. No. 174445
# Successfully embedded data from G.R. No. 175025
# Successfully embedded data from G.R. No. 175558
# Successfully embedded data from G.R. No. 175932
# Successfully embedded data from G.R. No. 175980
# Successfully embedded data from G.R. No. 176085
# Successfully embedded data from G.R. No. 177320
# Successfully embedded data from G.R. No. 178593
# Successfully embedded data from G.R. No. 179469
# Successfully embedded data from G.R. No. 179579
# Successfully embedded data from G.R. No. 180157
# Successfully embedded data from G.R. No. 180168
# Successfully embedded data from G.R. No. 180784
# Successfully embedded data from G.R. No. 180989
# Successfully embedded data from G.R. No. 181368
# Successfully embedded data from G.R. No. 181485
# Successfully embedded data from G.R. No. 181497
# Successfully embedded data from G.R. No. 181974
# Successfully embedded data from G.R. No. 182197
# Successfully embedded data from G.R. No. 182650
# Successfully embedded data from G.R. No. 182769
# Successfully embedded data from G.R. No. 183093
# Successfully embedded data from G.R. No. 183132
# Successfully embedded data from G.R. No. 183444
# Successfully embedded data from G.R. No. 183622
# Successfully embedded data from G.R. No. 184015
# Successfully embedded data from G.R. No. 184109
# Successfully embedded data from G.R. No. 184556
# Successfully embedded data from G.R. No. 184851
# Successfully embedded data from G.R. No. 185053
# Successfully embedded data from G.R. No. 185212
# Successfully embedded data from G.R. No. 185463
# Successfully embedded data from G.R. No. 185572
# Successfully embedded data from G.R. No. 185582
# Successfully embedded data from G.R. No. 185665
# Successfully embedded data from G.R. No. 185669
# Successfully embedded data from G.R. No. 186123
# Successfully embedded data from G.R. No. 186132
# Successfully embedded data from G.R. No. 186226
# Successfully embedded data from G.R. No. 186269
# Successfully embedded data from G.R. No. 186541
# Successfully embedded data from G.R. No. 186720
# Successfully embedded data from G.R. No. 186961
# Successfully embedded data from G.R. No. 186983
# Successfully embedded data from G.R. No. 187122
# Successfully embedded data from G.R. No. 187157
# Successfully embedded data from G.R. No. 187229
# Successfully embedded data from G.R. No. 187490
# Successfully embedded data from G.R. No. 187567
# Successfully embedded data from G.R. No. 187733
# Successfully embedded data from G.R. No. 187736
# Successfully embedded data from G.R. No. 187926
# Successfully embedded data from G.R. No. 188132
# Successfully embedded data from G.R. No. 188722
# Successfully embedded data from G.R. No. 189021
# Successfully embedded data from G.R. No. 189191
# Successfully embedded data from G.R. No. 189327
# Successfully embedded data from G.R. No. 189496
# Successfully embedded data from G.R. No. 189647
# Successfully embedded data from G.R. No. 190022
# Successfully embedded data from G.R. No. 190375
# Successfully embedded data from G.R. No. 190794
# Successfully embedded data from G.R. No. 191365
# Successfully embedded data from G.R. No. 192085
# Successfully embedded data from G.R. No. 192274
# Successfully embedded data from G.R. No. 192558
# Successfully embedded data from G.R. No. 192565
# Successfully embedded data from G.R. No. 192984
# Successfully embedded data from G.R. No. 193065
# Successfully embedded data from G.R. No. 193346
# Successfully embedded data from G.R. No. 193667
# Successfully embedded data from G.R. No. 193978
# Successfully embedded data from G.R. No. 194306
# Successfully embedded data from G.R. No. 194320
# Successfully embedded data from G.R. No. 194653
# Successfully embedded data from G.R. No. 194710
# Successfully embedded data from G.R. No. 196271
# Successfully embedded data from G.R. No. 196830
# Successfully embedded data from G.R. No. 197043
# Successfully embedded data from G.R. No. 197540
# Successfully embedded data from G.R. No. 197788
# Successfully embedded data from G.R. No. 197815
# Successfully embedded data from G.R. No. 199150
# Successfully embedded data from G.R. Nos. 153304-05
# Successfully embedded data from G.R. Nos. 174941
# Successfully embedded data from G.R. Nos. 180631-33
# Successfully embedded data from G.R. Nos. 186659-710
# Successfully embedded data from G.R. Nos. 191288 & 191304
# Successfully embedded data from A.M. No. P-11-2907 (Formerly A.M. OCA IPI No. 09-3113-P)
# Successfully embedded data from A.M. No. P-11-2950 (Formerly A.M. No. 11-6-62-MCTC)
# Successfully embedded data from A.M. No. P-12-3027 [Formerly OCA I.P.I. No. 11-3584-P]
# Successfully embedded data from A.M. OCA IPI No. 11-184-CA-J
# Successfully embedded data from G.R. No. 151038
# Successfully embedded data from G.R. No. 152093
# Successfully embedded data from G.R. No. 153569
# Successfully embedded data from G.R. No. 154061
# Successfully embedded data from G.R. No. 154670
# Successfully embedded data from G.R. No. 158239
# Successfully embedded data from G.R. No. 162100
# Successfully embedded data from G.R. No. 164197
# Successfully embedded data from G.R. No. 166482
# Successfully embedded data from G.R. No. 166858
# Successfully embedded data from G.R. No. 168120
# Successfully embedded data from G.R. No. 169084
# Successfully embedded data from G.R. No. 170839
# Successfully embedded data from G.R. No. 171750
# Successfully embedded data from G.R. No. 173648
# Successfully embedded data from G.R. No. 173774
# Successfully embedded data from G.R. No. 173794
# Successfully embedded data from G.R. No. 174005
# Successfully embedded data from G.R. No. 174082
# Successfully embedded data from G.R. No. 174089
# Successfully embedded data from G.R. No. 174208
# Successfully embedded data from G.R. No. 175602
# Successfully embedded data from G.R. No. 176298
# Successfully embedded data from G.R. No. 177498
# Successfully embedded data from G.R. No. 177578
# Successfully embedded data from G.R. No. 177743
# Successfully embedded data from G.R. No. 177780
# Successfully embedded data from G.R. No. 177839
# Successfully embedded data from G.R. No. 177936
# Successfully embedded data from G.R. No. 178021
# Successfully embedded data from G.R. No. 179497
# Successfully embedded data from G.R. No. 179884
# Successfully embedded data from G.R. No. 180236
# Successfully embedded data from G.R. No. 181184
# Successfully embedded data from G.R. No. 181701
# Successfully embedded data from G.R. No. 181962
# Successfully embedded data from G.R. No. 183050
# Successfully embedded data from G.R. No. 183350
# Successfully embedded data from G.R. No. 183822
# Successfully embedded data from G.R. No. 184219
# Successfully embedded data from G.R. No. 185064
# Successfully embedded data from G.R. No. 185124
# Successfully embedded data from G.R. No. 185128 [Formerly UDK No. 13980]
# Successfully embedded data from G.R. No. 185280
# Successfully embedded data from G.R. No. 185960
# Successfully embedded data from G.R. No. 186235
# Successfully embedded data from G.R. No. 186392
# Successfully embedded data from G.R. No. 187021
# Successfully embedded data from G.R. No. 187107
# Successfully embedded data from G.R. No. 188288
# Successfully embedded data from G.R. No. 188726
# Successfully embedded data from G.R. No. 189151
# Successfully embedded data from G.R. No. 189947
# Successfully embedded data from G.R. No. 190436
# Successfully embedded data from G.R. No. 191336
# Successfully embedded data from G.R. No. 191412
# Successfully embedded data from G.R. No. 192813
# Successfully embedded data from G.R. No. 193362
# Successfully embedded data from G.R. No. 193484
# Successfully embedded data from G.R. No. 193672
# Successfully embedded data from G.R. No. 193943
# Successfully embedded data from G.R. No. 194139
# Successfully embedded data from G.R. No. 195002
# Successfully embedded data from G.R. Nos. 177857-58
# Successfully embedded data from A.C. No. 6622
# Successfully embedded data from A.C. No. 6910
# Successfully embedded data from A.C. No. 7360
# Successfully embedded data from A.M. No. 11-7-10-SC
# Successfully embedded data from A.M. No. MTJ-10-1770
# Successfully embedded data from A.M. No. MTJ-11-1779 (Formerly A.M. OCA IPI No. 09-2191-MTJ)
# Successfully embedded data from A.M. No. MTJ-12-1804 (Formerly A.M. OCA I.P.I. No. 09-2179-MTJ)
# Successfully embedded data from A.M. No. P-06-2186 (Formerly A.M. OCA I.P.I. No. 05-2256-P)
# Successfully embedded data from A.M. No. P-06-2241 (Formerly OCA IPI No. 06-2422-P)
# Successfully embedded data from A.M. No. P-06-2246 [Formerly OCA I.P.I. No. 05-2287-P]
# Successfully embedded data from A.M. No. P-09-2647
# Successfully embedded data from A.M. No. P-11-2952 (Formerly A.M. OCA I.P.I. No. 10-3502-P)
# Successfully embedded data from A.M. No. P-11-2965 [Formerly OCA I.P.I. No. 08-3029-P]
# Successfully embedded data from A.M. No. P-11-2983 [Formerly OCA I.P.I. No. 10-3439-P]
# Successfully embedded data from A.M. No. P-11-3024
# Successfully embedded data from A.M. No. P-12-3062 (Formerly A.M. OCA IPI No. 11-3651-P)
# Successfully embedded data from A.M. No. P-12-3067 [formerly A.M. OCA IPI No. 10-3400-P]
# Successfully embedded data from A.M. No. RTJ-10-2257
# Successfully embedded data from A.M. RTJ-12-2317 (Formerly OCA I.P.I. No. 10-3378-RTJ)
# Successfully embedded data from B.M. No. 2112
# Successfully embedded data from G.R. No 176556
# Successfully embedded data from G.R. No. 132073
# Successfully embedded data from G.R. No. 153511
# Successfully embedded data from G.R. No. 154952
# Successfully embedded data from G.R. No. 155680
# Successfully embedded data from G.R. No. 159746
# Successfully embedded data from G.R. No. 161090
# Successfully embedded data from G.R. No. 167732
# Successfully embedded data from G.R. No. 168771
# Successfully embedded data from G.R. No. 169272
# Successfully embedded data from G.R. No. 169957
# Successfully embedded data from G.R. No. 170038
# Successfully embedded data from G.R. No. 170071
# Successfully embedded data from G.R. No. 171050
# Successfully embedded data from G.R. No. 171337
# Successfully embedded data from G.R. No. 171359
# Successfully embedded data from G.R. No. 171514
# Successfully embedded data from G.R. No. 172035
# Successfully embedded data from G.R. No. 172418
# Successfully embedded data from G.R. No. 172438
# Successfully embedded data from G.R. No. 172829
# Successfully embedded data from G.R. No. 173171
# Successfully embedded data from G.R. No. 174893
# Successfully embedded data from G.R. No. 175123
# Successfully embedded data from G.R. No. 175552
# Successfully embedded data from G.R. No. 175851
# Successfully embedded data from G.R. No. 176251
# Successfully embedded data from G.R. No. 176570
# Successfully embedded data from G.R. No. 178477
# Successfully embedded data from G.R. No. 179265
# Successfully embedded data from G.R. No. 179545
# Successfully embedded data from G.R. No. 180027
# Successfully embedded data from G.R. No. 180036
# Successfully embedded data from G.R. No. 180245
# Successfully embedded data from G.R. No. 181250
# Successfully embedded data from G.R. No. 181491
# Successfully embedded data from G.R. No. 181995
# Successfully embedded data from G.R. No. 182059
# Successfully embedded data from G.R. No. 182069
# Successfully embedded data from G.R. No. 183260
# Successfully embedded data from G.R. No. 183573
# Successfully embedded data from G.R. No. 183987
# Successfully embedded data from G.R. No. 184300
# Successfully embedded data from G.R. No. 184482
# Successfully embedded data from G.R. No. 185460
# Successfully embedded data from G.R. No. 185491
# Successfully embedded data from G.R. No. 185527
# Successfully embedded data from G.R. No. 185806
# Successfully embedded data from G.R. No. 187298
# Successfully embedded data from G.R. No. 187316
# Successfully embedded data from G.R. No. 187425
# Successfully embedded data from G.R. No. 188612
# Successfully embedded data from G.R. No. 189041
# Successfully embedded data from G.R. No. 189082
# Successfully embedded data from G.R. No. 189755
# Successfully embedded data from G.R. No. 189767
# Successfully embedded data from G.R. No. 190102
# Successfully embedded data from G.R. No. 190810
# Successfully embedded data from G.R. No. 191109
# Successfully embedded data from G.R. No. 192250
# Successfully embedded data from G.R. No. 192377
# Successfully embedded data from G.R. No. 192450
# Successfully embedded data from G.R. No. 192591
# Successfully embedded data from G.R. No. 192885
# Successfully embedded data from G.R. No. 192999
# Successfully embedded data from G.R. No. 193089
# Successfully embedded data from G.R. No. 193636
# Successfully embedded data from G.R. No. 193679
# Successfully embedded data from G.R. No. 194581
# Successfully embedded data from G.R. No. 194608
# Successfully embedded data from G.R. No. 194785
# Successfully embedded data from G.R. No. 194945
# Successfully embedded data from G.R. No. 195770
# Successfully embedded data from G.R. No. 196425
# Successfully embedded data from G.R. No. 196990
# Successfully embedded data from G.R. No. 198554
# Successfully embedded data from G.R. No. 198585
# Successfully embedded data from G.R. No. 198588
# Successfully embedded data from G.R. No. 198589
# Successfully embedded data from G.R. No. 198860
# Successfully embedded data from G.R. No. 200242
# Successfully embedded data from G.R. No. 200922
# Successfully embedded data from G.R. No. 202242
# Successfully embedded data from A.C. No. 1900
# Successfully embedded data from A.C. No. 6368
# Successfully embedded data from A.C. No. 9387 (Formerly CBD Case No. 05-1562)
# Successfully embedded data from A.M. No. 06-9-525-RTC
# Successfully embedded data from A.M. No. 09-8-6-SC
# Successfully embedded data from A.M. No. 12-6-10-SC
# Successfully embedded data from A.M. No. 12-6-11-SC
# Successfully embedded data from A.M. No. 14061- Ret
# Successfully embedded data from A.M. No. MTJ-11-1796 (Formerly OCA I.P.I. No. 10-2279-MTJ)
# Successfully embedded data from A.M. No. MTJ-12-1811 [Formerly A.M. OCA IPI No. 10-2313-MTJ]
# Successfully embedded data from A.M. No. MTJ-12-1812 [Formerly A.M. OCA IPI No. 10-2250-MTJ]
# Successfully embedded data from A.M. No. P-08-2573
# Successfully embedded data from A.M. No. P-09-2646 (Formerly OCA I.P.I. No. 08-2911-P)
# Successfully embedded data from A.M. No. P-10-2867 [Formerly A.M. OCA IPI No. 09-3255-P]
# Successfully embedded data from A.M. No. P-11-2986 [Formerly A.M. OCA IPI No. 10-3460-P]
# Successfully embedded data from A.M. No. P-12-3035 [Formerly OCA I.P.I. No. 11- 3619-P]
# Successfully embedded data from A.M. No. P-12-3036 (Formerly OCA I.P.I. No. 10-3384-P)
# Successfully embedded data from A.M. No. P-12-3061 [Formerly OCA-IPI No. 08-3022-P]
# Successfully embedded data from A.M. No. P-12-3064 (Formerly A.M. OCA IPI No. 09-3180-P)
# Successfully embedded data from A.M. No. RTJ-10-2216 (Formerly A.M. OCA I.P.I. No. 08-2788-RTJ)
# Successfully embedded data from A.M. No. RTJ-11-2258 (formerly A.M. OCA IPI No. 10-3340-RTJ)
# Successfully embedded data from A.M. No. SB-12-18-P
# Successfully embedded data from A.M. No. SCC-10-13-P
# Successfully embedded data from A.M. OCA IPI No. 09-3210-RTJ
# Successfully embedded data from G.R. No. 129822
# Successfully embedded data from G.R. No. 139930
# Successfully embedded data from G.R. No. 152662
# Successfully embedded data from G.R. No. 155996
# Successfully embedded data from G.R. No. 156869
# Successfully embedded data from G.R. No. 158597
# Successfully embedded data from G.R. No. 158755
# Successfully embedded data from G.R. No. 158891
# Successfully embedded data from G.R. No. 159108
# Successfully embedded data from G.R. No. 159709
# Successfully embedded data from G.R. No. 160641
# Successfully embedded data from G.R. No. 165285
# Successfully embedded data from G.R. No. 166044
# Successfully embedded data from G.R. No. 166758
# Successfully embedded data from G.R. No. 166884
# Successfully embedded data from G.R. No. 168208
# Successfully embedded data from G.R. No. 170026
# Successfully embedded data from G.R. No. 170509
# Successfully embedded data from G.R. No. 170783
# Successfully embedded data from G.R. No. 171038
# Successfully embedded data from G.R. No. 171209
# Successfully embedded data from G.R. No. 171591
# Successfully embedded data from G.R. No. 171671
# Successfully embedded data from G.R. No. 171905
# Successfully embedded data from G.R. No. 172349
# Successfully embedded data from G.R. No. 172642
# Successfully embedded data from G.R. No. 173012
# Successfully embedded data from G.R. No. 173390
# Successfully embedded data from G.R. No. 174007
# Successfully embedded data from G.R. No. 174156
# Successfully embedded data from G.R. No. 174181
# Successfully embedded data from G.R. No. 174214
# Successfully embedded data from G.R. No. 174297
# Successfully embedded data from G.R. No. 174369
# Successfully embedded data from G.R. No. 174809
# Successfully embedded data from G.R. No. 174937
# Successfully embedded data from G.R. No. 175055
# Successfully embedded data from G.R. No. 175350
# Successfully embedded data from G.R. No. 175430
# Successfully embedded data from G.R. No. 176184
# Successfully embedded data from G.R. No. 176671
# Successfully embedded data from G.R. No. 176692
# Successfully embedded data from G.R. No. 176783
# Successfully embedded data from G.R. No. 176893
# Successfully embedded data from G.R. No. 176949
# Successfully embedded data from G.R. No. 178046
# Successfully embedded data from G.R. No. 178626
# Successfully embedded data from G.R. No. 179015
# Successfully embedded data from G.R. No. 179018
# Successfully embedded data from G.R. No. 179059
# Successfully embedded data from G.R. No. 180308
# Successfully embedded data from G.R. No. 180572
# Successfully embedded data from G.R. No. 180615
# Successfully embedded data from G.R. No. 180966
# Successfully embedded data from G.R. No. 180974
# Successfully embedded data from G.R. No. 181136
# Successfully embedded data from G.R. No. 181548
# Successfully embedded data from G.R. No. 182316
# Successfully embedded data from G.R. No. 182486
# Successfully embedded data from G.R. No. 182572
# Successfully embedded data from G.R. No. 182716
# Successfully embedded data from G.R. No. 182920
# Successfully embedded data from G.R. No. 183623
# Successfully embedded data from G.R. No. 184467
# Successfully embedded data from G.R. No. 185335
# Successfully embedded data from G.R. No. 185346
# Successfully embedded data from G.R. No. 185522
# Successfully embedded data from G.R. No. 185663
# Successfully embedded data from G.R. No. 186469
# Successfully embedded data from G.R. No. 186722
# Successfully embedded data from G.R. No. 186730
# Successfully embedded data from G.R. No. 187188
# Successfully embedded data from G.R. No. 187512
# Successfully embedded data from G.R. No. 187604
# Successfully embedded data from G.R. No. 187744
# Successfully embedded data from G.R. No. 187951
# Successfully embedded data from G.R. No. 188302
# Successfully embedded data from G.R. No. 188329
# Successfully embedded data from G.R. No. 188978
# Successfully embedded data from G.R. No. 189418
# Successfully embedded data from G.R. No. 189697
# Successfully embedded data from G.R. No. 189999
# Successfully embedded data from G.R. No. 190336
# Successfully embedded data from G.R. No. 190422
# Successfully embedded data from G.R. No. 190793
# Successfully embedded data from G.R. No. 190875
# Successfully embedded data from G.R. No. 191563
# Successfully embedded data from G.R. No. 192241
# Successfully embedded data from G.R. No. 192334
# Successfully embedded data from G.R. No. 192413
# Successfully embedded data from G.R. No. 192474
# Successfully embedded data from G.R. No. 192716
# Successfully embedded data from G.R. No. 193665
# Successfully embedded data from G.R. No. 193676
# Successfully embedded data from G.R. No. 193808
# Successfully embedded data from G.R. No. 194106
# Successfully embedded data from G.R. No. 194255
# Successfully embedded data from G.R. No. 194781
# Successfully embedded data from G.R. No. 194795
# Successfully embedded data from G.R. No. 194880
# Successfully embedded data from G.R. No. 195137
# Successfully embedded data from G.R. No. 195534
# Successfully embedded data from G.R. No. 196201
# Successfully embedded data from G.R. No. 196870
# Successfully embedded data from G.R. No. 197371
# Successfully embedded data from G.R. No. 198402
# Successfully embedded data from G.R. No. 199403
# Successfully embedded data from G.R. No. 200653
# Successfully embedded data from G.R. No. 201112
# Successfully embedded data from G.R. Nos. 120744-46
# Successfully embedded data from G.R. Nos. 155322-29
# Successfully embedded data from A.C. No. 7591
# Successfully embedded data from A.C. No. 9154 (Formerly CBD No. 07-1965)
# Successfully embedded data from A.M. No. 10-1-13-SC
# Successfully embedded data from A.M. No. 11-10-1-SC
# Successfully embedded data from A.M. No. 12-2-03-0
# Successfully embedded data from A.M. No. 12-2-6-SC
# Successfully embedded data from A.M. No. CA-12-25-P
# Successfully embedded data from A.M. No. P-09-2686 (Formerly OCA I.P.I No. 06-2441-P)
# Successfully embedded data from A.M. No. P-11-3019
# Successfully embedded data from G.R. No. 146754
# Successfully embedded data from G.R. No. 151898
# Successfully embedded data from G.R. No. 152272
# Successfully embedded data from G.R. No. 155109
# Successfully embedded data from G.R. No. 160882
# Successfully embedded data from G.R. No. 162322
# Successfully embedded data from G.R. No. 165132
# Successfully embedded data from G.R. No. 166216
# Successfully embedded data from G.R. No. 169628
# Successfully embedded data from G.R. No. 170964
# Successfully embedded data from G.R. No. 171251
# Successfully embedded data from G.R. No. 171765
# Successfully embedded data from G.R. No. 172712
# Successfully embedded data from G.R. No. 173155
# Successfully embedded data from G.R. No. 173586
# Successfully embedded data from G.R. No. 173857
# Successfully embedded data from G.R. No. 174173
# Successfully embedded data from G.R. No. 174792
# Successfully embedded data from G.R. No. 175263
# Successfully embedded data from G.R. No. 175781
# Successfully embedded data from G.R. No. 175924
# Successfully embedded data from G.R. No. 176628
# Successfully embedded data from G.R. No. 178367
# Successfully embedded data from G.R. No. 179652
# Successfully embedded data from G.R. No. 182522
# Successfully embedded data from G.R. No. 183367
# Successfully embedded data from G.R. No. 183449
# Successfully embedded data from G.R. No. 184406
# Successfully embedded data from G.R. No. 184478
# Successfully embedded data from G.R. No. 184719
# Successfully embedded data from G.R. No. 184885
# Successfully embedded data from G.R. No. 185255
# Successfully embedded data from G.R. No. 185568
# Successfully embedded data from G.R. No. 186030
# Successfully embedded data from G.R. No. 186499
# Successfully embedded data from G.R. No. 187073
# Successfully embedded data from G.R. No. 187521
# Successfully embedded data from G.R. No. 188103
# Successfully embedded data from G.R. No. 188670
# Successfully embedded data from G.R. No. 190293
# Successfully embedded data from G.R. No. 190342
# Successfully embedded data from G.R. No. 190559
# Successfully embedded data from G.R. No. 191703
# Successfully embedded data from G.R. No. 191913
# Successfully embedded data from G.R. No. 192180
# Successfully embedded data from G.R. No. 193279
# Successfully embedded data from G.R. No. 193861
# Successfully embedded data from G.R. No. 193983
# Successfully embedded data from G.R. No. 194445
# Successfully embedded data from G.R. No. 194645
# Successfully embedded data from G.R. No. 195191
# Successfully embedded data from G.R. No. 195239
# Successfully embedded data from G.R. No. 195546
# Successfully embedded data from G.R. No. 196358
# Successfully embedded data from G.R. No. 197124
# Successfully embedded data from G.R. No. 197987
# Successfully embedded data from G.R. Nos. 162335 & 162605
# Successfully embedded data from G.R. Nos. 189161 & 189173
# Successfully embedded data from A.C. No. 9608
# Successfully embedded data from A.M. No. P-08-2441 [Formerly A.M. No. 08-2-53-MTC]
# Successfully embedded data from A.M. No. P-12-3097 (Formerly OCA IPI No. 09-3311-P)
# Successfully embedded data from A.M. No. RTJ-10-2244 [Formerly A.M. No. 10-7-222-RTC]
# Successfully embedded data from A.M. No. RTJ-12-2334
# Successfully embedded data from A.M. No. RTJ-96-1336
# Successfully embedded data from Adm. Case No. 9058
# Successfully embedded data from G.R. No. 152642
# Successfully embedded data from G.R. No. 156296
# Successfully embedded data from G.R. No. 157649
# Successfully embedded data from G.R. No. 158920
# Successfully embedded data from G.R. No. 159594
# Successfully embedded data from G.R. No. 160453
# Successfully embedded data from G.R. No. 166259
# Successfully embedded data from G.R. No. 167880
# Successfully embedded data from G.R. No. 168499
# Successfully embedded data from G.R. No. 169380
# Successfully embedded data from G.R. No. 170029
# Successfully embedded data from G.R. No. 171579
# Successfully embedded data from G.R. No. 172471
# Successfully embedded data from G.R. No. 172778
# Successfully embedded data from G.R. No. 173336
# Successfully embedded data from G.R. No. 173773
# Successfully embedded data from G.R. No. 174077
# Successfully embedded data from G.R. No. 175481
# Successfully embedded data from G.R. No. 175792
# Successfully embedded data from G.R. No. 176172
# Successfully embedded data from G.R. No. 176791
# Successfully embedded data from G.R. No. 176834
# Successfully embedded data from G.R. No. 177392
# Successfully embedded data from G.R. No. 177657
# Successfully embedded data from G.R. No. 178431
# Successfully embedded data from G.R. No. 178622
# Successfully embedded data from G.R. No. 178630
# Successfully embedded data from G.R. No. 178789
# Successfully embedded data from G.R. No. 179031
# Successfully embedded data from G.R. No. 179754
# Successfully embedded data from G.R. No. 180076
# Successfully embedded data from G.R. No. 180705
# Successfully embedded data from G.R. No. 180804
# Successfully embedded data from G.R. No. 181042
# Successfully embedded data from G.R. No. 181052
# Successfully embedded data from G.R. No. 181664
# Successfully embedded data from G.R. No. 181699
# Successfully embedded data from G.R. No. 182475
# Successfully embedded data from G.R. No. 183026
# Successfully embedded data from G.R. No. 183100
# Successfully embedded data from G.R. No. 183446
# Successfully embedded data from G.R. No. 183553
# Successfully embedded data from G.R. No. 183774
# Successfully embedded data from G.R. No. 183827
# Successfully embedded data from G.R. No. 184056
# Successfully embedded data from G.R. No. 184181
# Successfully embedded data from G.R. No. 184601
# Successfully embedded data from G.R. No. 185386
# Successfully embedded data from G.R. No. 186463
# Successfully embedded data from G.R. No. 187732
# Successfully embedded data from G.R. No. 188225
# Successfully embedded data from G.R. No. 189330
# Successfully embedded data from G.R. No. 189689
# Successfully embedded data from G.R. No. 189984
# Successfully embedded data from G.R. No. 191193
# Successfully embedded data from G.R. No. 191761
# Successfully embedded data from G.R. No. 192076
# Successfully embedded data from G.R. No. 192108
# Successfully embedded data from G.R. No. 192221
# Successfully embedded data from G.R. No. 192294
# Successfully embedded data from G.R. No. 192330
# Successfully embedded data from G.R. No. 192486
# Successfully embedded data from G.R. No. 192951
# Successfully embedded data from G.R. No. 192975
# Successfully embedded data from G.R. No. 193857
# Successfully embedded data from G.R. No. 195168
# Successfully embedded data from G.R. No. 196877
# Successfully embedded data from G.R. No. 197466
# Successfully embedded data from G.R. No. 197598
# Successfully embedded data from G.R. No. 198050
# Successfully embedded data from G.R. No. 198770
# Successfully embedded data from G.R. No. 199433
# Successfully embedded data from G.R. No. 199875
# Successfully embedded data from G.R. No. 200238
# Successfully embedded data from G.R. No. 200792
# Successfully embedded data from G.R. No. 200868
# Successfully embedded data from G.R. No. 201587
# Successfully embedded data from G.R. Nos. 162144-54
# Successfully embedded data from A.C. No. 6733
# Successfully embedded data from A.M. No. MTJ-11-1787 [Formerly A.M. No. 08-5-146-MeTC]
# Successfully embedded data from A.M. No. P-06-2196 (Formerly OCA I.P.I. No. 05-2272-P)
# Successfully embedded data from A.M. No. RTJ-11-2289 (formerly A.M. OCA IPI NO. 11-3656-RTJ)
# Successfully embedded data from A.M. No. RTJ-12-2316 (Formerly A.M. No. 09-7-280-RTC)
# Successfully embedded data from A.M. No. RTJ-12-2321
# Successfully embedded data from A.M. No. RTJ-12-2333 [Formerly OCA-I.P.I. No. 11-3721-RTJ]
# Successfully embedded data from G.R. No. 153478
# Successfully embedded data from G.R. No. 153852
# Successfully embedded data from G.R. No. 159370
# Successfully embedded data from G.R. No. 160260
# Successfully embedded data from G.R. No. 163182
# Successfully embedded data from G.R. No. 164051
# Successfully embedded data from G.R. No. 166462
# Successfully embedded data from G.R. No. 166803
# Successfully embedded data from G.R. No. 168331
# Successfully embedded data from G.R. No. 168987
# Successfully embedded data from G.R. No. 169391
# Successfully embedded data from G.R. No. 170454
# Successfully embedded data from G.R. No. 170677
# Successfully embedded data from G.R. No. 170732
# Successfully embedded data from G.R. No. 171845
# Successfully embedded data from G.R. No. 171855
# Successfully embedded data from G.R. No. 172825
# Successfully embedded data from G.R. No. 173211
# Successfully embedded data from G.R. No. 173610
# Successfully embedded data from G.R. No. 174582
# Successfully embedded data from G.R. No. 174715
# Successfully embedded data from G.R. No. 175155
# Successfully embedded data from G.R. No. 175177
# Successfully embedded data from G.R. No. 175990
# Successfully embedded data from G.R. No. 176162
# Successfully embedded data from G.R. No. 176579
# Successfully embedded data from G.R. No. 177140
# Successfully embedded data from G.R. No. 177232
# Successfully embedded data from G.R. No. 177357
# Successfully embedded data from G.R. No. 178584
# Successfully embedded data from G.R. No. 178909
# Successfully embedded data from G.R. No. 181089
# Successfully embedded data from G.R. No. 182018
# Successfully embedded data from G.R. No. 182209
# Successfully embedded data from G.R. No. 183053
# Successfully embedded data from G.R. No. 184950
# Successfully embedded data from G.R. No. 185368
# Successfully embedded data from G.R. No. 186592
# Successfully embedded data from G.R. No. 188571
# Successfully embedded data from G.R. No. 189754
# Successfully embedded data from G.R. No. 189808
# Successfully embedded data from G.R. No. 189817
# Successfully embedded data from G.R. No. 189820
# Successfully embedded data from G.R. No. 192088
# Successfully embedded data from G.R. No. 192650
# Successfully embedded data from G.R. No. 192799
# Successfully embedded data from G.R. No. 193237
# Successfully embedded data from G.R. No. 194122
# Successfully embedded data from G.R. No. 194366
# Successfully embedded data from G.R. No. 194758
# Successfully embedded data from G.R. No. 195229
# Successfully embedded data from G.R. No. 196383
# Successfully embedded data from G.R. No. 196434
# Successfully embedded data from G.R. No. 196539
# Successfully embedded data from G.R. No. 196804
# Successfully embedded data from G.R. No. 197151
# Successfully embedded data from G.R. No. 197309
# Successfully embedded data from G.R. No. 197315
# Successfully embedded data from G.R. No. 198423
# Successfully embedded data from G.R. No. 198733
# Successfully embedded data from G.R. No. 199264
# Successfully embedded data from G.R. No. 199735
# Successfully embedded data from G.R. No. 201112
# Successfully embedded data from G.R. Nos. 130714 & 139634
# Successfully embedded data from G.R. Nos. 159561-62
# Successfully embedded data from G.R. Nos. 184903-04
# Successfully embedded data from A.C. No. 6753
# Successfully embedded data from A.M. No. MTJ-07-1666 (Formerly A.M. OCA I.P.I. No. 05-1761-MTJ)
# Successfully embedded data from A.M. No. P-06-2161 (Formerly A.M. No. OCA IPI No. 05-2115-P)
# Successfully embedded data from A.M. No. P-09-2597 (Formerly A.M. No. 08-12-356-MCTC)
# Successfully embedded data from A.M. No. P-10-2805 (formerly A.M. No. 10-4-57-MCTC)
# Successfully embedded data from A.M. No. P-11-2920 (Formerly OCA I.P.I. No. 09-3300-P)
# Successfully embedded data from A.M. No. P-12-3086 (Formerly A.M. No. 11-7-75-MCTC)
# Successfully embedded data from A.M. No. P-12-3087 (Formerly A.M. OCA IPI No. 08-2720-P)
# Successfully embedded data from A.M. No. RTJ-09-2179 [Formerly A.M. OCA I.P.I. No. 08-2873-RTJ]
# Successfully embedded data from A.M. No. RTJ-09-2182 [FORMERLY A.M. NO. 08-3007-RTJ]
# Successfully embedded data from A.M. No. RTJ-11-2271 (Formerly OCA I.P.I. No. 09-3239-RTJ)
# Successfully embedded data from A.M. OCA IPI No. 04-1606-MTJ
# Successfully embedded data from G.R. No. 148607
# Successfully embedded data from G.R. No. 148843
# Successfully embedded data from G.R. No. 153799
# Successfully embedded data from G.R. No. 160446
# Successfully embedded data from G.R. No. 161122
# Successfully embedded data from G.R. No. 162372
# Successfully embedded data from G.R. No. 162809
# Successfully embedded data from G.R. No. 165355
# Successfully embedded data from G.R. No. 166467
# Successfully embedded data from G.R. No. 167366
# Successfully embedded data from G.R. No. 170787
# Successfully embedded data from G.R. No. 171107
# Successfully embedded data from G.R. No. 171118
# Successfully embedded data from G.R. No. 171219
# Successfully embedded data from G.R. No. 173036
# Successfully embedded data from G.R. No. 173425
# Successfully embedded data from G.R. No. 174376
# Successfully embedded data from G.R. No. 174669
# Successfully embedded data from G.R. No. 174982
# Successfully embedded data from G.R. No. 175170
# Successfully embedded data from G.R. No. 175284
# Successfully embedded data from G.R. No. 176343
# Successfully embedded data from G.R. No. 177438
# Successfully embedded data from G.R. No. 177711
# Successfully embedded data from G.R. No. 179054
# Successfully embedded data from G.R. No. 179115
# Successfully embedded data from G.R. No. 182045
# Successfully embedded data from G.R. No. 182230
# Successfully embedded data from G.R. No. 182523
# Successfully embedded data from G.R. No. 183097
# Successfully embedded data from G.R. No. 183533
# Successfully embedded data from G.R. No. 184500
# Successfully embedded data from G.R. No. 184606
# Successfully embedded data from G.R. No. 185282
# Successfully embedded data from G.R. No. 186002
# Successfully embedded data from G.R. No. 187052
# Successfully embedded data from G.R. No. 187801
# Successfully embedded data from G.R. No. 188417
# Successfully embedded data from G.R. No. 188979
# Successfully embedded data from G.R. No. 189486
# Successfully embedded data from G.R. No. 189774
# Successfully embedded data from G.R. No. 190680
# Successfully embedded data from G.R. No. 191062
# Successfully embedded data from G.R. No. 191128
# Successfully embedded data from G.R. No. 191753
# Successfully embedded data from G.R. No. 191837
# Successfully embedded data from G.R. No. 192117
# Successfully embedded data from G.R. No. 192945
# Successfully embedded data from G.R. No. 193753
# Successfully embedded data from G.R. No. 193789
# Successfully embedded data from G.R. No. 193854
# Successfully embedded data from G.R. No. 194014
# Successfully embedded data from G.R. No. 195592
# Successfully embedded data from G.R. No. 195619
# Successfully embedded data from G.R. No. 195909
# Successfully embedded data from G.R. No. 196161
# Successfully embedded data from G.R. No. 196231
# Successfully embedded data from G.R. No. 196355
# Successfully embedded data from G.R. No. 197205
# Successfully embedded data from G.R. No. 197528
# Successfully embedded data from G.R. No. 198662
# Successfully embedded data from G.R. No. 199082
# Successfully embedded data from G.R. No. 199084
# Successfully embedded data from G.R. No. 199547
# Successfully embedded data from G.R. No. 200529
# Successfully embedded data from G.R. No. 200951
# Successfully embedded data from G.R. No. 202914
# Successfully embedded data from G.R. Nos. 154470-71
# Successfully embedded data from G.R. Nos. 177857-58
# Successfully embedded data from G.R. Nos. 180880-81
# Number of documents embedded: 957

# %% [markdown]
# # Query (compare each embedding)

# %% [markdown]
# ## MongoDB Vector Search Index (currently not working)

# %%
# Function to generate embedding for the query string
query = "murder"
query_embedding = generate_embedding(query)

# %% [markdown]
# MongoDB Vector Search (currently not working with chunk embeddings)

# %%
# results = collection.aggregate([
#     {
#         "$project": {
#             "identifier": 1,
#             "petitioner": 1,
#             "respondent": 1,
#             "text_chunk_embeddings": 1,
#             "chunk_match_scores": {
#                 "$map": {
#                     "input": "$text_chunk_embeddings",
#                     "as": "chunk_embedding",
#                     "in": {
#                         "$let": {
#                             "vars": {
#                                 "search_result": {
#                                     "$meta": {
#                                         "$vectorSearch": {
#                                             "queryVector": query_embedding,
#                                             "path": "$$chunk_embedding"
#                                         }
#                                     }
#                                 }
#                             },
#                             "in": "$$search_result.score"
#                         }
#                     }
#                 }
#             }
#         }
#     },
#     {
#         "$addFields": {
#             "max_score": { "$max": "$chunk_match_scores" }
#         }
#     },
#     {
#         "$sort": { "max_score": -1 }
#     },
#     {
#         "$limit": 5
#     }
# ])

# for document in results:
#     print(f'Identifier: {document["identifier"]},\nPetitioner: {document["petitioner"]},\nRespondent: {document["respondent"]}\n\n')

# %% [markdown]
# This is the code for Vector Search for no chunks yet --> will try for chunking here (multiple arrays of embeddings)

# %%
results = collection.aggregate([
  {"$vectorSearch": {
    "queryVector": generate_embedding(query),
    "path": "text_chunk_embeddings",
    # This is an optimization parameter that tells MongoDB how many candidate matches to consider internally, before returning the final results.
    # Higher number can improve the accuracy of the results, but may increase the computation size
    "numCandidates": 100,  
    "limit": 5,
    "index": "TextSemanticSearch",
      }}
]);

for document in results:
    print(f'Identifier: {document["identifier"]},\nPetitioner: {document["petitioner"]},\nRespondent: {document["respondent"]}\n\n')

# %%
# TRIAL: for multiple chunk embeddings

# Verify the query vector generation
query_vector = generate_embedding("your query text")
print("Generated Query Vector:", query_vector)
print("Query Vector Length:", len(query_vector))

# Verify the documents in the collection
sample_docs = collection.find({}, {"text_chunk_embeddings": 1}).limit(5)
for doc in sample_docs:
    print("Sample Document:", doc)

# Simplified pipeline to debug the search stage
pipeline = [
    {
        "$search": {
            "index": "TextSemanticSearch",
            "knnBeta": {
                "vector": query_vector,
                "path": "text_chunk_embeddings",
                "k": 50  # Adjust the number of nearest neighbors
            }
        }
    },
    {
        "$project": {
            "text_chunk_embeddings": 1,
            "score": {"$meta": "searchScore"}
        }
    }
-0.009571811184287071, -0.014386546798050404, 0.05241662263870239, -0.055241718888282776, -0.08707775920629501, 0.07108261436223984, 0.055976271629333496, -0.022771663963794708, 0.006569169461727142, 0.06141088157892227, 0.12266714125871658, 0.030830204486846924, -0.01082103792577982, 0.07675305753946304, -0.06547784805297852, 0.03724827989935875, 0.01789112575352192, -0.013945885002613068, -0.04327822104096413, 0.006868136581033468, 0.017643695697188377, 0.0022283161524683237, 0.11561395972967148, -0.013627070002257824, 0.07082811743021011, 0.06337343156337738, 0.03809234872460365, -0.08977776020765305, -0.03008267655968666, -0.030663762241601944, 0.0036967098712921143, 0.010449178516864777, 0.04622649401426315, 0.034311044961214066, -0.11819609254598618, -0.03439173847436905, -0.022864852100610733, -0.05420604720711708, 0.13063472509384155, 0.08284071832895279, 0.032909225672 ...
# No results found.

# %%
# Insert a test document with a single embedding
test_doc = {
    "text_chunk_embeddings": [
        [0.1] * 384
    ]
}

collection.insert_one(test_doc)

# Run the same pipeline
results = collection.aggregate(pipeline)

# Print the results
found_results = False
for document in results:
    found_results = True
    print("Search Result:", document)

if not found_results:
    print("No results found.")
# Out:
# No results found.

# %%
collection.delete_one({"text_chunk_embeddings": [[0.1] * 384]})

print("Document deleted.")
# Out:
# Document deleted.

# %%
results

# %%
for document in results:
    print(document)

# %% [markdown]
# Debugging

# %%
# Check a few documents in the collection
sample_docs = collection.find().limit(1)
for doc in sample_docs:
    print(doc)
# Out:
# {'_id': ObjectId('664e4e1e1fd27d4ee67ccb12'), 'url': 'https://elibrary.judiciary.gov.ph/thebookshelf/showdocs/1/24291', 'title': 'A.C. No. 5098', 'parties': 'JOSEFINA M. ANIÑON, COMPLAINANT, VS. ATTY. CLEMENCIO SABITSANA, JR., RESPONDENT.', 'date': '2012-04-11', 'division': 'SECOND DIVISION', 'type': 'DECISION', 'presiding_justice': 'BRION, J.', 'text': 'We resolve this disbarment complaint against Atty. Clemencio Sabitsana, Jr. who is charged of: (1) violating the lawyer’s duty to preserve confidential information received from his client; [1] and (2) violating the prohibition on representing conflicting interests. [2] In her complaint, Josefina M. Aniñon ( complainant ) related that she previously engaged the legal services of Atty. Sabitsana in the preparation and execution in her favor of a Deed of Sale over a parcel of land owned by her late common-law husband, Brigido Caneja, Jr. Atty. Sabitsana allegedly violated her confidence when he subsequently filed a civil case against her for the annulment of the Deed of Sale in behalf of Zenaida L. Cañete, the legal wife of Brigido Caneja, Jr. The complainant accused Atty. Sabitsana of using the confidential information he obtained from her in filing the civil case. Atty. Sabitsana admitted having advised the complainant in the preparation and execution of the Deed of Sale. However, he denied having received any confidential information. Atty. Sabitsana asserted that the present disbarment complaint was instigated by one Atty. Gabino Velasquez, Jr., the notary of the disbarment complaint who lost a court case against him (Atty. Sabitsana) and had instigated the complaint for this reason. The Findings of the IBP Investigating Commissioner In our Resolution dated November 22, 1999, we referred the disbarment complaint to the Commission on Bar Discipline of the Integrated Bar of the Philippines (IBP) for investigation, report and recommendation. In his Report and Recommendation dated November 28, 2003, IBP Commissioner Pedro A. Magpayo Jr. found
#  -0.0813990980386734,
#  -0.004572825040668249,
#  0.042777422815561295,
#  -0.017306137830018997,
#  0.020867876708507538,
#  -0.09463150054216385,
#  0.08990132063627243,
#  -0.05650775879621506,
#  0.004976453725248575,
#  -0.02287565916776657,
#  0.05193144828081131,
#  -0.07725029438734055,
#  -0.0008477892843075097,
#  0.028105825185775757,
#  -0.09692451357841492,
#  -0.01960160583257675,
#  0.08237870037555695,
#  -0.0807034894824028,
#  -0.026989813894033432,
#  0.015568776987493038,
#  0.06309793144464493,
#  0.04247575253248215,
#  -0.07267090678215027,
#  -0.041025009006261826,
#  -0.08886347711086273,
#  0.015270702540874481,
#  0.007387976627796888,
#  -0.02450518123805523,
#  -1.215727785108811e-08,
#  -0.048601407557725906,
#  0.0006524380878545344,
#  -0.03938567638397217,
#  -0.07788447290658951,
#  -0.002838079584762454,
#  0.0018209099071100354,
#  -0.030020615085959435,
#  -0.012409782037138939,
#  0.01860630325973034,
#  0.043045297265052795,
#  -0.0018051204970106483,
#  0.06840754300355911,
#  0.01739070564508438,
#  0.04091159626841545,
#  0.03526877611875534,
#  -0.05484890192747116,
#  0.027213051915168762,
#  0.008570837788283825,
#  -0.04619691148400307,
#  -0.026539677754044533,
#  -0.0879092887043953,
#  0.032474689185619354,
#  0.05501505360007286,
#  0.024009693413972855,
#  0.014874119311571121,
#  -0.057578496634960175,
#  0.035349633544683456,
#  0.06954806298017502,
#  0.05030127242207527,
#  0.06597110629081726,
#  -0.043462544679641724,
#  0.019443688914179802,
#  -0.007778883911669254,
#  0.010657473467290401,
#  -0.04264817014336586,
#  -0.07549045234918594,
#  0.019249355420470238,
#  0.02837022952735424,
#  -0.02344459667801857,
#  -0.07542873919010162,
#  0.020239125937223434,
#  0.03347610682249069,
#  0.02211439423263073,
#  -0.050788816064596176,
#  0.0005545653984881938,
#  -0.04841821640729904,
#  0.03658629581332207,
#  0.007410599384456873,
#  0.010982169769704342,
#  -0.003435382153838873,
#  0.0034947730600833893,
#  0.015039408579468727,
#  0.00847142469137907,
#  0.06003131717443466,
#  0.08763960003852844,
#  0.009149888530373573,
#  0.03539352864027023,
#  0.05740699917078018,
#  -0.06978657841682434,
#  0.007877501659095287,
#  0.20077836513519287,
#  0.033798351883888245,
#  0.07449596375226974,
#  -0.03561222180724144]

# %%
# Generate the query embedding
query = "murder"
query_embedding = generate_embedding(query)

# Define the aggregation pipeline for vector search
pipeline = [
    {
        "$search": {
            "index": "TextSemanticSearch",  # Ensure this matches the name of your search index
            "knnBeta": {
                "vector": query_embedding,
                "path": "text_chunk_embeddings",
                "k": 5  # Number of nearest neighbors
            }
        }
    },
    {
        "$project": {
            "identifier": 1,
            "score": {"$meta": "searchScore"}
        }
    }
]

# Run the aggregation query
results = collection.aggregate(pipeline)

# Print the results
for document in results:
    print(f"Identifier: {document['identifier']}, Score: {document['score']}")

# %%
results

# %% [markdown]
# ## FAISS

# %%
pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0-cp39-cp39-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in d:\apps\anaconda3\envs\my_env\lib\site-packages (from faiss-cpu) (1.26.4)
# Downloading faiss_cpu-1.8.0-cp39-cp39-win_amd64.whl (14.5 MB)
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.5 MB 2.9 MB/s eta 0:00:05
#    --- ------------------------------------ 1.2/14.5 MB 8.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.1/14.5 MB 11.3 MB/s eta 0:00:02
#    -------- ------------------------------- 3.1/14.5 MB 13.3 MB/s eta 0:00:01
#    -------- ------------------------------- 3.1/14.5 MB 13.3 MB/s eta 0:00:01
#    -------- ------------------------------- 3.1/14.5 MB 13.3 MB/s eta 0:00:01
#    -------- ------------------------------- 3.1/14.5 MB 13.3 MB/s eta 0:00:01
#    --------- ------------------------------ 3.5/14.5 MB 8.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.5 MB 9.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.5 MB 9.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.5 MB 9.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.5 MB 9.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.5 MB 9.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.5 MB 9.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.5 MB 9.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.5 MB 9.2 MB/s eta 0:00:02
#    --------------- ------------------------ 5.6/14.5 MB 6.5 MB/s eta 0:00:02
#    ------------------- -------------------- 7.2/14.5 MB 8.0 MB/s eta 0:00:01
#    -------------------- ------------------- 7.3/14.5 MB 8.1 MB/s eta 0:00:01
#    -------------------- ------------------- 7.3/14.5 MB 8.1 MB/s eta 0:00:01
#    -------------------- ------------------- 7.3/14.5 MB 8.1 MB/s eta 0:00:01
#    -------------------- ------------------- 7.3/14.5 MB 8.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.7/14.5 MB 7.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.3/14.5 MB 9.2 MB/s eta 0:00:01
#    -------------------------------- ------- 12.0/14.5 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------ --- 13.4/14.5 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.5 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.5 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.5 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 14.0/14.5 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  14.5/14.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------- 14.5/14.5 MB 14.9 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import faiss
import numpy as np

# %%
query = "murder"
query_embedding = np.array(generate_embedding(query)).astype('float32')

# %% [markdown]
# Current time: 11 seconds (900+ documents)

# %%
# might be too slow with large dataset because it loads the whole dataset into python 
# maybe needs to load in batches to load incrementally instead (?????????)

# Load embeddings from MongoDB
documents = collection.find({}, {"text_chunk_embeddings": 1, "text_chunks": 1, "_id": 1})
embeddings = []
ids = []
chunks = []
chunk_texts = []

for doc in documents:
    for i, emb in enumerate(doc['text_chunk_embeddings']):
        embeddings.append(emb)
        ids.append(doc['_id'])
        chunks.append(i)
        chunk_texts.append(doc['text_chunks'][i])

# %%
embeddings = np.array(embeddings).astype('float32')

# %%
# Create FAISS index
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

# %%
k = 5  # number of nearest neighbors
D, I = index.search(query_embedding.reshape(1, -1), k)

# %% [markdown]
# Using Euclidean distance (L2)
#
# Distances:
# - Distances close to 0 indicate high similarity.
# - Larger distances indicate lower similarity.

# %%
# Print the results
print("Nearest Neighbors:")
for dist, idx in zip(D[0], I[0]):
    print(f"Document ID: {ids[idx]}, Chunk Index: {chunks[idx]}, Distance: {dist}")
    print(f"Chunk Text: {chunk_texts[idx]}")
    print("----")
# Out:
# Nearest Neighbors:
# Document ID: 664e4e1e1fd27d4ee67ccc83, Chunk Index: 29, Distance: 0.9719419479370117
# Chunk Text: shall be deemed guilty of homicide and be punished by reclusion temporal .
