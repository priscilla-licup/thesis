# %% [markdown]
# # GPU Setup

# %%
import torch

# Check if GPU is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Using GPU: NVIDIA GeForce RTX 3060

# %% [markdown]
# # Libraries

# %%
import pymongo
import tensorflow as tf
from langchain.text_splitter import RecursiveCharacterTextSplitter
from sentence_transformers import SentenceTransformer

# %% [markdown]
# # MongoDB Connection

# %%
# MongoDB Connection String
client = pymongo.MongoClient("mongodb+srv://priscillalicup:bs62gnFzjoBQnJ03@cluster0.uskxsig.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client.supreme_court_jurisprudence
collection = db.year_2021_zip

# %% [markdown]
# # Model

# %%
# Ensure GPU usage for SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2', device=device)

# %% [markdown]
# # Recursive Chunking Function

# %%
# Recursive Chunking
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,  # Adjusted chunk size for mini-LM
    chunk_overlap=50,  # Adding some overlap to maintain context between chunks
    separators=["\n\n", "\n", "(?<=\. )", " "],
    length_function=len
)

# %% [markdown]
# # Embedding Function

# %%
def generate_embedding(text):
  return model.encode(text).tolist()

# %% [markdown]
# # Embedding all documents in a DB

# %% [markdown]
# ONLY RUN IF NO EMBEDDINGS IN DATABASE YET

# %%
# ONLY RUN IF NO EMBEDDINGS IN DATABASE YET

# Append embeddings to MongoDB
# -------------------------------------------- COMMENT OUT BELOW
counter = 0
try:
    for doc in collection.find({'text': {"$exists": True}}):
        # Check if embeddings already exist
        if 'text_chunk_embeddings' in doc:
            print(f"Embeddings already exist for document {str(doc['identifier'])}")
            counter += 1
            continue

        # Chunk the document text
        chunks = text_splitter.split_text(doc['text'])

        # Generate embeddings for each chunk
        chunk_embeddings = [generate_embedding(chunk) for chunk in chunks]

        # Store the chunks and their embeddings in the document
        doc['text_chunks'] = chunks
        doc['text_chunk_embeddings'] = chunk_embeddings

        # Check the document size
        try:
            collection.replace_one({'_id': doc['_id']}, doc)
            print(f"Successfully embedded data from {str(doc['identifier'])}")
        except pymongo.errors.DocumentTooLarge as e:
            print(f"Document too large for identifier {str(doc['identifier'])}: {e}")
            # pprint.pprint(doc)  # Print the document causing the issue
            
        counter += 1
except Exception as e:
    print(f"An error occurred: {e}")
finally:
    print(f"Number of documents embedded: {counter}")
# Out:
# Embeddings already exist for document A.C. No. 11959
# Embeddings already exist for document A.C. No. 12690
# Embeddings already exist for document A.M. No. MTJ-16-1880 [Formerly OCA IPI No. 13-2565-MTJ]
# Embeddings already exist for document A.M. No. P-21-015 [Formerly A.M. No. 14-2-24-MTC]
# Embeddings already exist for document G.R. No. 192809
# Embeddings already exist for document G.R. No. 200642
# Embeddings already exist for document G.R. No. 202105
# Embeddings already exist for document G.R. No. 203194
# Embeddings already exist for document G.R. No. 205261
# Embeddings already exist for document G.R. No. 205385
# Embeddings already exist for document G.R. No. 205979
# Embeddings already exist for document G.R. No. 207522
# Embeddings already exist for document G.R. No. 207619
# Embeddings already exist for document G.R. No. 208465
# Embeddings already exist for document G.R. No. 211239
# Embeddings already exist for document G.R. No. 211571
# Embeddings already exist for document G.R. No. 211691
# Embeddings already exist for document G.R. No. 213212
# Embeddings already exist for document G.R. No. 213425
# Embeddings already exist for document G.R. No. 213789
# Embeddings already exist for document G.R. No. 216656
# Embeddings already exist for document G.R. No. 219340
# Embeddings already exist for document G.R. No. 223547
# Embeddings already exist for document G.R. No. 228999
# Embeddings already exist for document G.R. No. 229811
# Embeddings already exist for document G.R. No. 230426
# Embeddings already exist for document G.R. No. 231038
# Embeddings already exist for document G.R. No. 231545
# Embeddings already exist for document G.R. No. 231679
# Embeddings already exist for document G.R. No. 232062
# Embeddings already exist for document G.R. No. 232329
# Embeddings already exist for document G.R. No. 232611
# Embeddings already exist for document G.R. No. 232688
# Embeddings already exist for document G.R. No. 233420
# Embeddings already exist for document G.R. No. 233437
# Embeddings already exist for document G.R. No. 234384
# Embeddings already exist for document G.R. No. 234514
# Embeddings already exist for document G.R. No. 235364
# Embeddings already exist for document G.R. No. 236900
# Embeddings already exist for document G.R. No. 237620
# Embeddings already exist for document G.R. No. 237646
# Embeddings already exist for document G.R. No. 239221
# Embeddings already exist for document G.R. No. 240447
# Embeddings already exist for document G.R. No. 240507
# Embeddings already exist for document G.R. No. 241126
# Embeddings already exist for document G.R. No. 241850
# Embeddings already exist for document G.R. No. 242328
# Embeddings already exist for document G.R. No. 244051
# Embeddings already exist for document G.R. No. 246053
# Embeddings already exist for document G.R. No. 246088
# Embeddings already exist for document G.R. No. 246702
# Embeddings already exist for document G.R. No. 246986
# Embeddings already exist for document G.R. No. 247982
# Embeddings already exist for document G.R. No. 248907
# Embeddings already exist for document G.R. No. 249168
# Embeddings already exist for document G.R. No. 249196
# Embeddings already exist for document G.R. No. 249358
# Embeddings already exist for document G.R. No. 250159
# Embeddings already exist for document G.R. No. 251178
# Embeddings already exist for document G.R. No. 252198
# Embeddings already exist for document G.R. No. 253253
# Embeddings already exist for document G.R. No. 253715
# Embeddings already exist for document G.R. Nos. 218485-86 and 218493-97
# Embeddings already exist for document G.R. Nos. 218532-33
# Embeddings already exist for document G.R. Nos. 221253-54
# Embeddings already exist for document G.R. Nos. 237432-33
# Embeddings already exist for document G.R. Nos. 247689-90
# Embeddings already exist for document A.C. No. 11599
# Embeddings already exist for document A.C. No. 6766
# Embeddings already exist for document A.M. No. CA-20-36-P
# Embeddings already exist for document G.R. No. 201380
# Embeddings already exist for document G.R. No. 203942
# Embeddings already exist for document G.R. No. 203946
# Embeddings already exist for document G.R. No. 204405
# Embeddings already exist for document G.R. No. 204567
# Embeddings already exist for document G.R. No. 204997
# Embeddings already exist for document G.R. No. 207958
# Embeddings already exist for document G.R. No. 210072
# Embeddings already exist for document G.R. No. 210245
# Embeddings already exist for document G.R. No. 212126
# Embeddings already exist for document G.R. No. 213001
# Embeddings already exist for document G.R. No. 213400
# Embeddings already exist for document G.R. No. 216587
# Embeddings already exist for document G.R. No. 217583
# Embeddings already exist for document G.R. No. 227467
# Embeddings already exist for document G.R. No. 233118
# Embeddings already exist for document G.R. No. 234999
# Embeddings already exist for document G.R. No. 235358
# Embeddings already exist for document G.R. No. 241699
# Embeddings already exist for document G.R. No. 249002
# Embeddings already exist for document G.R. No. 252865
# Embeddings already exist for document G.R. No. 255602
# Embeddings already exist for document G.R. No. 256285
# Embeddings already exist for document A.M. No. RTJ-19-2552 (formerly OCA IPI No. 13-4139-P)
# Embeddings already exist for document G.R. No. 181764
# Embeddings already exist for document G.R. No. 182630
# Embeddings already exist for document G.R. No. 191867
# Embeddings already exist for document G.R. No. 196199
# Embeddings already exist for document G.R. No. 200434
# Embeddings already exist for document G.R. No. 201631
# Embeddings already exist for document G.R. No. 204778
# Embeddings already exist for document G.R. No. 206579
# Embeddings already exist for document G.R. No. 207051
# Embeddings already exist for document G.R. No. 208912
# Embeddings already exist for document G.R. No. 210488
# Embeddings already exist for document G.R. No. 211122
# Embeddings already exist for document G.R. No. 211376
# Embeddings already exist for document G.R. No. 211443
# Embeddings already exist for document G.R. No. 213287
# Embeddings already exist for document G.R. No. 214426
# Embeddings already exist for document G.R. No. 217148
# Embeddings already exist for document G.R. No. 219715
# Embeddings already exist for document G.R. No. 220674
# Embeddings already exist for document G.R. No. 221347
# Embeddings already exist for document G.R. No. 222908
# Embeddings already exist for document G.R. No. 224052
# Embeddings already exist for document G.R. No. 224189
# Embeddings already exist for document G.R. No. 225299
# Embeddings already exist for document G.R. No. 229506
# Embeddings already exist for document G.R. No. 233839
# Embeddings already exist for document G.R. No. 235316
# Embeddings already exist for document G.R. No. 238905
# Embeddings already exist for document G.R. No. 240671
# Embeddings already exist for document G.R. No. 242087
# Embeddings already exist for document G.R. No. 246816
# Embeddings already exist for document G.R. No. 248113
# Embeddings already exist for document G.R. No. 248518
# Embeddings already exist for document G.R. No. 248643
# Embeddings already exist for document G.R. No. 249131
# Embeddings already exist for document G.R. No. 249500
# Embeddings already exist for document G.R. No. 251669
# Embeddings already exist for document G.R. No. 252007
# Document too large for identifier G.R. No. 252578: 'update' command document too large
# Successfully embedded data from G.R. No. 252965
# Successfully embedded data from G.R. No. 254328
# Successfully embedded data from G.R. Nos. 200070-71
# Successfully embedded data from G.R. Nos. 219630-31
# Successfully embedded data from G.R. Nos. 231538-39
# Successfully embedded data from G.R. Nos. 240163 & 240168-69
# Successfully embedded data from A.C. No. 12719 (Formerly CBD Case No. 17-5316)
# Successfully embedded data from A.C. No. 12798
# Successfully embedded data from A.C. No. 12826
# Successfully embedded data from A.C. No. 12835
# Successfully embedded data from A.C. No. 12881
# Successfully embedded data from A.C. No. 9701
# Successfully embedded data from A.M. No. 20-08-05-SC
# Successfully embedded data from A.M. No. P-19-3966 (Formerly OCA IPI No. 18-4802-P)
# Successfully embedded data from A.M. No. P-19-3966 [Formerly OCA IPI No. 18-4802-P]
# Successfully embedded data from A.M. No. RTJ-20-2588 [Formerly OCA I.P.I. No. 14-4336-RTJ]
# Successfully embedded data from A.M. No. RTJ-21-2606 (formerly A.M. No. 20-12-164-RTC)
# Successfully embedded data from G.R. No. 194167
# Successfully embedded data from G.R. No. 195236
# Successfully embedded data from G.R. No. 196323
# Successfully embedded data from G.R. No. 197147
# Successfully embedded data from G.R. No. 198277
# Successfully embedded data from G.R. No. 198529
# Successfully embedded data from G.R. No. 200608
# Successfully embedded data from G.R. No. 200635
# Successfully embedded data from G.R. No. 200772
# Successfully embedded data from G.R. No. 202151
# Successfully embedded data from G.R. No. 202724
# Successfully embedded data from G.R. No. 202761
# Successfully embedded data from G.R. No. 202900
# Successfully embedded data from G.R. No. 203420
# Successfully embedded data from G.R. No. 203539
# Successfully embedded data from G.R. No. 203756
# Successfully embedded data from G.R. No. 204526
# Successfully embedded data from G.R. No. 206892
# Successfully embedded data from G.R. No. 207507
# Successfully embedded data from G.R. No. 208981
# Successfully embedded data from G.R. No. 209440
# Successfully embedded data from G.R. No. 209551
# Successfully embedded data from G.R. No. 209712 [Formerly UDK-14994]
# Successfully embedded data from G.R. No. 211253
# Successfully embedded data from G.R. No. 211687
# Successfully embedded data from G.R. No. 213815
# Successfully embedded data from G.R. No. 217879
# Successfully embedded data from G.R. No. 219325
# Successfully embedded data from G.R. No. 219916
# Successfully embedded data from G.R. No. 220558
# Successfully embedded data from G.R. No. 221554
# Successfully embedded data from G.R. No. 222129
# Successfully embedded data from G.R. No. 222311
# Successfully embedded data from G.R. No. 222972
# Successfully embedded data from G.R. No. 223694
# Successfully embedded data from G.R. No. 224720-23
# Successfully embedded data from G.R. No. 224729
# Successfully embedded data from G.R. No. 226935
# Successfully embedded data from G.R. No. 227227
# Successfully embedded data from G.R. No. 227258
# Successfully embedded data from G.R. No. 228011
# Successfully embedded data from G.R. No. 228165
# Successfully embedded data from G.R. No. 229183
# Successfully embedded data from G.R. No. 229451
# Successfully embedded data from G.R. No. 230528
# Successfully embedded data from G.R. No. 230679
# Successfully embedded data from G.R. No. 232176
# Successfully embedded data from G.R. No. 232814
# Successfully embedded data from G.R. No. 233507
# Successfully embedded data from G.R. No. 233681
# Successfully embedded data from G.R. No. 233737
# Successfully embedded data from G.R. No. 234191
# Successfully embedded data from G.R. No. 235424
# Successfully embedded data from G.R. No. 235865
# Successfully embedded data from G.R. No. 236725
# Successfully embedded data from G.R. No. 236804
# Successfully embedded data from G.R. No. 236920
# Successfully embedded data from G.R. No. 237291
# Successfully embedded data from G.R. No. 237514
# Successfully embedded data from G.R. No. 237874
# Successfully embedded data from G.R. No. 238128
# Successfully embedded data from G.R. No. 238213
# Successfully embedded data from G.R. No. 238660
# Successfully embedded data from G.R. No. 239138
# Successfully embedded data from G.R. No. 239190
# Successfully embedded data from G.R. No. 239505
# Successfully embedded data from G.R. No. 239644
# Successfully embedded data from G.R. No. 240144
# Successfully embedded data from G.R. No. 241302
# Successfully embedded data from G.R. No. 241610
# Successfully embedded data from G.R. No. 242096
# Successfully embedded data from G.R. No. 242539
# Successfully embedded data from G.R. No. 242684
# Successfully embedded data from G.R. No. 243984
# Successfully embedded data from G.R. No. 244115
# Successfully embedded data from G.R. No. 244140
# Successfully embedded data from G.R. No. 244545
# Successfully embedded data from G.R. No. 244570
# Successfully embedded data from G.R. No. 244815
# Successfully embedded data from G.R. No. 246255
# Successfully embedded data from G.R. No. 246451
# Successfully embedded data from G.R. No. 246542
# Successfully embedded data from G.R. No. 247428
# Successfully embedded data from G.R. No. 247778
# Successfully embedded data from G.R. No. 247906
# Successfully embedded data from G.R. No. 250147
# Successfully embedded data from G.R. No. 250205
# Successfully embedded data from G.R. No. 250321
# Successfully embedded data from G.R. No. 252087
# Successfully embedded data from G.R. Nos. 203138-40
# Successfully embedded data from G.R. Nos. 232724-27
# Successfully embedded data from G.R. Nos. 236177-210
# Successfully embedded data from G.R. Nos. 242904-05
# Successfully embedded data from P.E.T. Case No. 005
# Successfully embedded data from UDK-16615
# Successfully embedded data from A.C. No. 11477 (Formerly CBD Case No. 12-3535)
# Successfully embedded data from A.C. No. 12875
# Successfully embedded data from A.C. No. 12876 [Formerly CBD Case No. 15-4823]
# Successfully embedded data from A.C. No. 12912
# Successfully embedded data from A.M. No. 07-4-188-RTC
# Successfully embedded data from A.M. No. 20-07-10-SC
# Successfully embedded data from A.M. No. P-18-3873 (Formerly OCA IPI No. 18-4858-P)
# Successfully embedded data from A.M. No. RTJ 20-2596 (Formerly OCA IPI No. 16-4590-RTJ)
# Successfully embedded data from A.M. No. RTJ-17-2494 (FORMERLY A.M. No. 16-11-03-SC)
# Successfully embedded data from A.M. No. SB-14-21-J
# Successfully embedded data from A.M. RTJ-20-2600 (Formerly OCA IPI No. 19-4952-RTJ)
# Successfully embedded data from AM. No. P-21-4102 [Formerly A.M. No. 18-04-42-MTC]
# Successfully embedded data from G.R. No. 171054
# Successfully embedded data from G.R. No. 187113
# Successfully embedded data from G.R. No. 192332
# Successfully embedded data from G.R. No. 193305
# Successfully embedded data from G.R. No. 195217
# Successfully embedded data from G.R. No. 195987
# Successfully embedded data from G.R. No. 196158
# Successfully embedded data from G.R. No. 198015
# Successfully embedded data from G.R. No. 198832
# Successfully embedded data from G.R. No. 200555
# Successfully embedded data from G.R. No. 202820
# Successfully embedded data from G.R. No. 203785
# Successfully embedded data from G.R. No. 204152
# Successfully embedded data from G.R. No. 204272
# Successfully embedded data from G.R. No. 205257
# Successfully embedded data from G.R. No. 205466
# Successfully embedded data from G.R. No. 205630
# Successfully embedded data from G.R. No. 205725
# Successfully embedded data from G.R. No. 205950
# Successfully embedded data from G.R. No. 207647
# Successfully embedded data from G.R. No. 207675
# Successfully embedded data from G.R. No. 209601
# Successfully embedded data from G.R. No. 210976
# Successfully embedded data from G.R. No. 213821
# Successfully embedded data from G.R. No. 214485
# An error occurred: you are over your space quota, using 515 MB of 512 MB, full error: {'ok': 0, 'errmsg': 'you are over your space quota, using 515 MB of 512 MB', 'code': 8000, 'codeName': 'AtlasError'}
# Number of documents embedded: 282
